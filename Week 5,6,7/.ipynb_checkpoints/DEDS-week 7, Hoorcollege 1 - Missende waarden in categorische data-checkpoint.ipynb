# %% [markdown]
# # DEDS-week 7, Hoorcollege 1 - Missende waarden in categorische data

# %% [markdown]
# ## Libraries importeren

# %%
import pandas as pd
import pyodbc
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2252\1118874489.py in <module>
#       1 import pandas as pd
#       2 import pyodbc
# ----> 3 from ydata_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %% [markdown]
# We importeren een extra library, die we vorige week nog niet gebruikten: ydata_profiling, waaruit we ProfileReport halen. Waar deze voor is, komt verderop aan bod.

# %% [markdown]
# ## DB-connecties maken

# %%
sales_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/jelle/OneDrive - De Haagse Hogeschool/GO gemoderniseerd/go_sales_vervuild.accdb;')

# %% [markdown]
# ## Dataframe aanmaken vanuit SELECT op databasetabel

# %%
product = pd.read_sql("SELECT * FROM product", sales_conn)
product
# Out:
# <ipython-input-3-4b76bf69317f>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql("SELECT * FROM product", sales_conn)
#     PRODUCT_NUMBER  INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST  \
# 0               53          10-1-2021                 8           28.55
# 1               54          10-1-2021                 8           35.33
# 2               55               None                 8               4
# 3               56          10-1-2021                 8               9
# 4               57          10-1-2021                 9              40
# ..             ...                ...               ...             ...
# 110            108         27-12-2019                19          472.22
# 111            109         10-12-2019                20              35
# 112            110  Blue Steel Putter                20              60
# 113            111         15-12-2019                20            81.8
# 114            112          10-1-2020                21               6
#
#               MARGIN    PRODUCT_IMAGE LANGUAGE  \
# 0                .28    P53ME2CA8.jpg       EN
# 1                .33    P54ME2CA8.jpg     None
# 2                 .5    P55ME2CA8.jpg       EN
# 3                 .5    P56ME2CA8.jpg     None
# 4                 .5    P57ME2TL9.jpg       EN
# ..               ...              ...      ...
# 110              .43             None       EN
# 111              .43  P109GE5PT20.jpg       EN
# 112               .5  P110GE5PT20.jpg       EN
# 113  P111GE5PT20.jpg              .55       EN
# 114              .33             None       EN
#
#                        PRODUCT_NAME  \
# 0             Firefly Climbing Lamp
# 1                   Firefly Charger
# 2      Firefly Rechargeable Battery
# 3                 Granite Chalk Bag
# 4                       Granite Ice
# ..                              ...
# 110  Lady Hailstorm Steel Woods Set
# 111               Course Pro Putter
# 112                      10-12-2019
# 113           Blue Steel Max Putter
# 114     Course Pro Golf and Tee Set
#
#                                            DESCRIPTION
# 0    This climbing lamp is water-resistant. It come...
# 1    Power charger for the Firefly Climbing Lamp. T...
# 2    Rechargeable battery pack for the Firefly Clim...
# 3    Nylon web bag perfect for holding several stic...
# 4    A general purpose mountaineering axe for snow ...
# ..                                                 ...
# 110  These steel woods are manufactured to exact to...
# 111  High quality putter is cast  from a soft yello...
# 112  This premium putter has copper mixed with ligh...
# 113  Putter head is composed from a single piece of...
# 114  Set includes two premium golf ball and an asso...
#
# [115 rows x 9 columns]

# %% [markdown]
# ## Kwaliteitsoverzicht

# %%
profile = ProfileReport(product, title = 'Kwaliteitsrapportage product')
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# Met het geïmporteerde rapport kunnen we een statistisch overzicht maken van een aantal kengetallen en correlaties in deze dataset. Enige nadeel: het duurt vrij lang voordat dit standaardrapport klaar is. Met name het tabblad "Alerts" onder "Overview" is interessant: die doet namelijk onder andere uitspraken over de datakwaliteit en missende waarden mogen daarin uiteraard niet ontbreken. Klik er voor de aardigheid gewoon eens doorheen en dan zie je wat Profiling allemaal voor je uit kan rekenen. Het is altijd goed om dit soort statistieken inzichtelijk te hebben voor snel inzicht in je ingeladen dataset, alvorens je daar mutaties op gaat toepassen.

# %% [markdown]
# ## Missende waarden afhandelen

# %% [markdown]
# ### Mogelijke methoden

# %% [markdown]
# Binnen de Data Science wordt er onderscheid gemaakt tussen 2 soorten data:
# - Categorische data: dit zijn datapunten waarop alleen een telberekening uitgevoerd kan worden.
# - Continue data: dit zijn getallen waarop verschillende berekeningen uitgevoerd kunnen worden (som, gemiddelde, mediaan, minimum, maximum, enzovoort). Hoe je in dit soort kolommen  missende data handelt komt woensdag aanbod.
#
# Hoe je missende waarden gaat invullen hangt heel sterk af van de soort data die in de betreffende kolom staat.
# 3 mogelijkheden voor het invullen van missende categorische datawaarden:
# - Waarden op 'onbekend' zetten. Gebruik deze methode als...
#     - De kolom allemaal verschillende waarden bevat, die niet afgeleid kunnen worden van waarden uit andere kolommen.
#     - Je op korte termijn niet geïnteresseerd bent in de analysemogelijkheden van deze kolom.
# - De waarde pakken die het vaakst voorkomt. Deze waarde wordt ook wel de modus genoemd. Gebruik deze methode als verreweg de meeste kolomvelden dezelfde waarde bevatten. De spreiding van waarden in je kolom is dan dus niet heel groot.
# - De 'buur-analyse'. In tegenstelling tot de andere twee methoden analyseer je hierbij het héle dataframe, in plaats van alleen de betreffende kolom met de missende waarden  Deze methode bestaat uit 2 stappen...
#     - Je zoekt naar overeenkomstige eigenschappen tussen rijen waarin de betreffende kolom niet is ingevuld.
#     - Je zoekt in de overkoepelende tabel naar rijen met die eigenschappen en probeert de juiste vulwaarden te achterhalen.
#
# In de onderstaande coderegels wordt per categorische kolom uit de producttabel achterhaald wat de juiste vulmethode is en wordt gedemonstreerd hoe je deze toepast in Python.

# %% [markdown]
# ### INTRODUCTION_DATE

# %% [markdown]
# De kolom INTRODUCTION_DATE bestaat alleen maar uit categorische data: er staan immers alleen datums in en geen getallen. Hoeveel missende waarden heeft deze kolom ook alweer? Laten we nog eens kijken...

# %%
product['INTRODUCTION_DATE'].isna().sum()
# Out:
# 5

# %% [markdown]
# Er zijn dus 5 waarden die nu nog missen. Laten we met de eerste methode oefenen: de 'onbekend'-methode. We besluiten namelijk ter plekke dat we niet geïnteresseerd zijn in het analyseren van introductiedata en dit is een geldig argument om deze methode te hanteren.

# %%
product['INTRODUCTION_DATE'] = product['INTRODUCTION_DATE'].fillna('onbekend')
product['INTRODUCTION_DATE'].isna().sum()
# Out:
# 0

# %% [markdown]
# Met de eerste coderegel vullen we de waarde 'onbekend' in met de .fillna(...)-methode. Met de tweede coderegel vragen we vervolgens nog een keer het aantal missende waarden op. We verwachten nu uiteraard dat deze 0 is en dat klopt ook! Operatie geslaagd dus!
#
# Maar wacht... eigenlijk hebben we nu toch geen waarde toegevoegd? Eerst miste er een regel en nu staat daar simpelweg 'onbekend', wat is hier het nut van? 2 redenen...
# - Als je Machine-Learningmodellen gaat trainen mag de data die je erin stopt helemaal geen missende waarden bevatten, anders crasht het model.
# - Je ziet in reporting-programma's, bijvoorbeeld Power BI & Qlikview, geen irritante 'blanks' meer staan. Je weet dus dat je op zijn minst heb nagedacht over hoe je missende waarden afhandelt.

# %% [markdown]
# ### LANGUAGE

# %% [markdown]
# Ook de kolom LANGUAGE bestaat alleen maar uit categorische data: er staat immers alleen tekst in en geen getallen. Hoeveel missende waarden hebben we hier ook alweer? Let's find out!

# %%
product['LANGUAGE'].isna().sum()
# Out:
# 6

# %% [markdown]
# We hebben vorige week al gezien dat bijna elke waarde in LANGUAGE 'EN' is. De categorische data in deze kolom is dus niet heel erg verdeeld, wat een goed argument is om de 6 ontbrekende waarden alsnog in te vullen met de 'modus'-methode. Uiteraard dienen we daarvoor eerst de modus te bepalen, voordat we .fillna(...) kunnen vullen. Dat doen we met onderstaande code:

# %%
modus = product['LANGUAGE'].mode()[0]
modus
# Out:
# 'EN'

# %% [markdown]
# We zien dat de waarde 'EN' inderdaad het vaakst voorkomt in LANGUAGE. We slaan deze op in de variabele 'modus'.

# %%
product['LANGUAGE'] = product['LANGUAGE'].fillna(modus)
product['LANGUAGE'].isna().sum()
# Out:
# 0

# %% [markdown]
# We gebruiken ten slotte de modus om de .fillna() in te vullen. Ook hier zien we dat de operatie is gelukt :-)

# %% [markdown]
# ### PRODUCT_TYPE_CODE

# %% [markdown]
# En... wéér hebben we categorische data. In PRODUCT_TYPE_CODE staan weliswaar getallen, maar zij geven categorieën aan. De som en/of het gemiddelde van dergelijke data berekenen zou heel erg onnuttig zijn.

# %%
product['PRODUCT_TYPE_CODE'].isna().sum()
# Out:
# 6

# %% [markdown]
# 6 missende rijen, mooi! Dan kunnen we aan de slag met de derde invulmethode voor categorische data: de 'buur'-analyse. De eerste stap omvat het maken van een subset van alle kolommen van rijen waar PRODUCT_TYPE_CODE leeg is om te kijken welke andere kolommen wél ingevuld zijn.

# %%
product.loc[product['PRODUCT_TYPE_CODE'].isna(), :]
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 8               61         10-1-2021              None              20     .5
# 16              69         15-2-2011              None           73.33    .33
# 36             114        15-12-2019              None              80     .6
# 65              28         15-2-2011              None              24     .2
# 88              51         10-1-2021              None              35     .5
# 104            102        10-12-2019              None          380.95    .51
#
#            PRODUCT_IMAGE       LANGUAGE              PRODUCT_NAME  \
# 8          P61ME2TL9.jpg             EN               Granite Axe
# 16        P69PA3EW11.jpg             EN                 Polar Ice
# 36   Course Pro Golf Bag             EN           P114GE5GA21.jpg
# 65         P28CE1PK4.jpg             EN        Canyon Mule Cooler
# 88                    EN  P51ME2CA8.jpg             Granite Belay
# 104      P102GE5IR18.jpg             EN  Hailstorm Titanium Irons
#
#                                            DESCRIPTION
# 8           Camping axe with clear coated wood handle.
# 16   Polar Ice sunglasses have polarized lenses to ...
# 36   High quality golf bag that includes carrying s...
# 65   A durable plastic cooler with hinged top, perf...
# 88   The Granite Belay is an ingenious single rope ...
# 104  Made entirely of pure titanium. The ultimate i...

# %% [markdown]
# In deze subset gaan we vervolgens op zoek naar gelijkenissen tussen rijen.

# %% [markdown]
# #### PRODUCT_NAME bevat 'Granite'

# %% [markdown]
# Het valt ons ten eerste op dat in 'PRODUCT_NAME' twee keer het woord 'Granite' voorkomt. Als we in het overkoepelende dataframe zoeken op rijen met productnamen die dit woord bevatten kunnen we misschien achterhalen welk producttype hier het vaakst bijhoort.

# %%
subset_product_name_contains_granite = product.loc[(~product['PRODUCT_NAME'].isna()) & (product['PRODUCT_NAME'].str.contains('Granite')), :]
subset_product_name_contains_granite
# Out:
#    PRODUCT_NUMBER                                  INTRODUCTION_DATE  \
# 3              56                                          10-1-2021
# 4              57                                          10-1-2021
# 5              58                                          10-1-2021
# 6              59                                          10-1-2021
# 7              60                                          10-1-2021
# 8              61                                          10-1-2021
# 9              62                                          10-1-2021
# 83             46                                          10-1-2021
# 86             49  Day or night signal mirror with gridded sighti...
# 87             50                                          10-1-2021
# 88             51                                          10-1-2021
# 89             52                                          10-1-2021
#
#    PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  PRODUCT_IMAGE       LANGUAGE  \
# 3                  8               9     .5  P56ME2CA8.jpg             EN
# 4                  9              40     .5  P57ME2TL9.jpg             EN
# 5                  9           57.13    .28  P58ME2TL9.jpg             EN
# 6                  9           46.15    .23             EN  P59ME2TL9.jpg
# 7                  9              10     .5  P60ME2TL9.jpg             EN
# 8               None              20     .5  P61ME2TL9.jpg             EN
# 9                  9           47.06     .4  P62ME2TL9.jpg             EN
# 83                 7           52.86    .28  P46ME2SY7.jpg             EN
# 86                 7            16.5     .5  P49ME2SY7.jpg             EN
# 87                 8               2     .5  P50ME2CA8.jpg             EN
# 88              None              35     .5             EN  P51ME2CA8.jpg
# 89                 8              19     .5  P52ME2CA8.jpg             EN
#
#                PRODUCT_NAME                                        DESCRIPTION
# 3         Granite Chalk Bag  Nylon web bag perfect for holding several stic...
# 4               Granite Ice  A general purpose mountaineering axe for snow ...
# 5            Granite Hammer  A solid hammer made with a solid hard wood han...
# 6            Granite Shovel  Shovel has removable aluminum handle and heat ...
# 7              Granite Grip  All-purpose stainless steel pliers. Sheath inc...
# 8               Granite Axe         Camping axe with clear coated wood handle.
# 9           Granite Extreme  The Edge Extreme is a collapsible plier-shaped...
# 83  Granite Climbing Helmet  This UIAA approved helmet fits adults and kids...
# 86    Granite Signal Mirror                                          10-1-2021
# 87        Granite Carabiner  Made from 12 mm rod stock aluminum and a radiu...
# 88            Granite Belay  The Granite Belay is an ingenious single rope ...
# 89           Granite Pulley                                               None

# %% [markdown]
# We zien hier dat producten die 'Granite' in hun naam hebben verreweg het vaakst bij producttype 9 horen. Vanaf hier kunnen we de aanname doen dat we missende waarden met productnamen met 'Granite' erin met 9 mogen invullen.

# %%
product.loc[(~product['PRODUCT_NAME'].isna()) & (product['PRODUCT_NAME'].str.contains('Granite')), 'PRODUCT_TYPE_CODE'] = subset_product_name_contains_granite['PRODUCT_TYPE_CODE'].fillna(9)
product['PRODUCT_TYPE_CODE'].isna().sum()
# Out:
# 4

# %% [markdown]
# Waarom is de code aan de linkerkant van '=' zo lang? Omdat we een gedeelte van het originele dataframe ('product') willen overschrijven. Gelukkig kunnen we aan de rechterkant van '=' de gemaakte subset gebruiken. Van de 6 rijen waren er 2 die 'Granite' bevatten en daarvan is de producttypecode inmiddels ingevuld. Er zouden dus nog 4 lege waarden over moeten blijven en dat klopt!

# %% [markdown]
# #### INTRODUCTION_DATE bevat jaar 2011 en 2019

# %%
product.loc[product['PRODUCT_TYPE_CODE'].isna(), :]
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 16              69         15-2-2011              None           73.33    .33
# 36             114        15-12-2019              None              80     .6
# 65              28         15-2-2011              None              24     .2
# 104            102        10-12-2019              None          380.95    .51
#
#            PRODUCT_IMAGE LANGUAGE              PRODUCT_NAME  \
# 16        P69PA3EW11.jpg       EN                 Polar Ice
# 36   Course Pro Golf Bag       EN           P114GE5GA21.jpg
# 65         P28CE1PK4.jpg       EN        Canyon Mule Cooler
# 104      P102GE5IR18.jpg       EN  Hailstorm Titanium Irons
#
#                                            DESCRIPTION
# 16   Polar Ice sunglasses have polarized lenses to ...
# 36   High quality golf bag that includes carrying s...
# 65   A durable plastic cooler with hinged top, perf...
# 104  Made entirely of pure titanium. The ultimate i...

# %% [markdown]
# Ten tweede zien we dat bij de ene 2 rijen waar de producttypecode mist, het jaartal 2011 is, bij de andere 2 rijen is dit 2019. Zou dat een goede tweede aanwijzing kunnen zijn? Let's find out! Hiervoor is het handig om eerst even een extra kolom 'INTRODUCTION_YEAR' te maken.

# %%
product['INTRODUCTION_YEAR'] = product['INTRODUCTION_DATE'].str[-4:]
product
# Out:
#     PRODUCT_NUMBER  INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST  \
# 0               53          10-1-2021                 8           28.55
# 1               54          10-1-2021                 8           35.33
# 2               55           onbekend                 8               4
# 3               56          10-1-2021                 8               9
# 4               57          10-1-2021                 9              40
# ..             ...                ...               ...             ...
# 110            108         27-12-2019                19          472.22
# 111            109         10-12-2019                20              35
# 112            110  Blue Steel Putter                20              60
# 113            111         15-12-2019                20            81.8
# 114            112          10-1-2020                21               6
#
#               MARGIN    PRODUCT_IMAGE LANGUAGE  \
# 0                .28    P53ME2CA8.jpg       EN
# 1                .33    P54ME2CA8.jpg       EN
# 2                 .5    P55ME2CA8.jpg       EN
# 3                 .5    P56ME2CA8.jpg       EN
# 4                 .5    P57ME2TL9.jpg       EN
# ..               ...              ...      ...
# 110              .43             None       EN
# 111              .43  P109GE5PT20.jpg       EN
# 112               .5  P110GE5PT20.jpg       EN
# 113  P111GE5PT20.jpg              .55       EN
# 114              .33             None       EN
#
#                        PRODUCT_NAME  \
# 0             Firefly Climbing Lamp
# 1                   Firefly Charger
# 2      Firefly Rechargeable Battery
# 3                 Granite Chalk Bag
# 4                       Granite Ice
# ..                              ...
# 110  Lady Hailstorm Steel Woods Set
# 111               Course Pro Putter
# 112                      10-12-2019
# 113           Blue Steel Max Putter
# 114     Course Pro Golf and Tee Set
#
#                                            DESCRIPTION INTRODUCTION_YEAR
# 0    This climbing lamp is water-resistant. It come...              2021
# 1    Power charger for the Firefly Climbing Lamp. T...              2021
# 2    Rechargeable battery pack for the Firefly Clim...              kend
# 3    Nylon web bag perfect for holding several stic...              2021
# 4    A general purpose mountaineering axe for snow ...              2021
# ..                                                 ...               ...
# 110  These steel woods are manufactured to exact to...              2019
# 111  High quality putter is cast  from a soft yello...              2019
# 112  This premium putter has copper mixed with ligh...              tter
# 113  Putter head is composed from a single piece of...              2019
# 114  Set includes two premium golf ball and an asso...              2020
#
# [115 rows x 10 columns]

# %% [markdown]
# Met bovenstaande code lees je de laatste 4 karakters uit van elke string die in de kolom 'INTRODUCTION_DATE' staat. Met zijn viertjes geven zij het jaartal weer, dat vervolgens wordt geëxporteerd naar een nieuwe kolom: 'INTRODUCTION_YEAR'.
#
# We zoeken weer in het overkoepelende dataframe op rijen met dezelfde eigenschappen (in dit geval: introductiejaar = 2011 OF 2019). Zo hopen we wederom te achterhalen welk producttype hier het vaakst bijhoort.

# %%
subset_introduction_year_2011_2019 = product.loc[(product['INTRODUCTION_YEAR'] == '2011') | (product['INTRODUCTION_YEAR'] == '2019'), :]
subset_introduction_year_2011_2019
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  \
# 10              63         15-2-2011                10
# 11              64         15-2-2011                10
# 15              68         15-2-2011                11
# 16              69         15-2-2011              None
# 20              73         15-2-2011                12
# 21              74         15-2-2011                12
# 23              76         15-2-2011                12
# 26              79         15-2-2011                13
# 33              86         15-2-2011                15
# 34              87         15-2-2011                15
# 36             114        15-12-2019              None
# 37             115        27-12-2019                21
# 38               1         15-2-2011                 1
# 39               2         15-2-2011                 1
# 40               3         15-2-2011                 1
# 41               4         15-2-2011                 1
# 42               5         15-2-2011                 1
# 44               7         15-2-2011                 1
# 48              11         15-2-2011                 2
# 50              13         15-2-2011                 2
# 55              18         15-2-2011                 3
# 58              21         15-2-2011                 3
# 59              22         15-2-2011                 3
# 62              25         15-2-2011                 4
# 63              26         15-2-2011                 4
# 65              28         15-2-2011              None
# 69              32         15-2-2011                 5
# 73              36         15-2-2011                 5
# 77              40         15-2-2011                 5
# 90              88         15-2-2011                15
# 92              90         15-2-2011                15
# 93              91         15-2-2011                16
# 94              92         15-2-2011                16
# 95              93         15-2-2011                16
# 96              94         15-2-2011                16
# 97              95         15-2-2011                16
# 98              96         15-2-2011                17
# 100             98         15-2-2011                17
# 101             99         15-2-2011                17
# 102            100         15-2-2011                17
# 103            101        15-12-2019                18
# 104            102        10-12-2019              None
# 105            103        10-12-2019                18
# 107            105        27-12-2019                19
# 108            106         5-12-2019                19
# 110            108        27-12-2019                19
# 111            109        10-12-2019                20
# 113            111        15-12-2019                20
#
#                                        PRODUCTION_COST           MARGIN  \
# 10                                                  30              .33
# 11                                                  20               .5
# 15                                               46.15              .23
# 16                                               73.33              .33
# 20                                                8.56              .28
# 21                                               11.43              .28
# 23                                               23.53               .4
# 26                                               92.58              .25
# 33                                                   2              .67
# 34                                                   2              .67
# 36                                                  80               .6
# 37                                                   5               .5
# 38                                                   4              .33
# 39                                                9.22              .23
# 40                                               15.93              .28
# 41                                                   5              .28
# 42                                               34.97               .3
# 44                                       P07CE1CG1.jpg              .28
# 48                                                 250              .28
# 50                                              392.57              .25
# 55                                                  86              .33
# 58                                               29.17              .17
# 59                                                  10              .33
# 62                                              166.66             None
# 63                                              213.33              .33
# 65                                                  24               .2
# 69   A high quality aluminum flashlight with Krypto...              .33
# 73                                               18.05               .4
# 77                                               17.97              .28
# 90                                                None               .7
# 92                                                 2.5              .63
# 93                                                   2               .6
# 94                                                   2               .6
# 95                                                   2               .6
# 96                                                   2               .6
# 97                                                   3               .5
# 98                                               16.43              .28
# 100                                                  3               .5
# 101                                                  2               .6
# 102                                                  3               .5
# 103                                             305.54              .43
# 104                                             380.95              .51
# 105                                             277.76              .43
# 107                                              555.9              .55
# 108                                             536.09              .43
# 110                                             472.22              .43
# 111                                                 35              .43
# 113                                               81.8  P111GE5PT20.jpg
#
#                                          PRODUCT_IMAGE  \
# 10                                      P63PA3WT10.jpg
# 11                                      P64PA3WT10.jpg
# 15                                      P68PA3EW11.jpg
# 16                                      P69PA3EW11.jpg
# 20                                      P73PA3KV12.jpg
# 21                                      P74PA3KV12.jpg
# 23                                      P76PA3KV12.jpg
# 26                                      P78PA3BN13.jpg
# 33                                      P86OP4IR15.jpg
# 34                                                  EN
# 36                                 Course Pro Golf Bag
# 37                                     P115GE5GA21.jpg
# 38                                       P01CE1CG1.jpg
# 39                                       P02CE1CG1.jpg
# 40                                       P03CE1CG1.jpg
# 41                                       P04CE1CG1.jpg
# 42                                       P05CE1CG1.jpg
# 44                                               46.38
# 48                                       P11CE1TN2.jpg
# 50                                       P13CE1TN2.jpg
# 55   The Hibernator is a three-season sleeping bag....
# 58                                       P21CE1SB3.jpg
# 59                                       P22CE1SB3.jpg
# 62                                       P25CE1PK4.jpg
# 63                                       P26CE1PK4.jpg
# 65                                       P28CE1PK4.jpg
# 69                                       P32CE1LT5.jpg
# 73                                       P36CE1LT5.jpg
# 77                                       P40CE1LT5.jpg
# 90                                      P86OP4IR15.jpg
# 92                                      P86OP4IR15.jpg
# 93                                      P91OP4SS16.jpg
# 94                                      P91OP4SS16.jpg
# 95                                      P91OP4SS16.jpg
# 96                                      P91OP4SS16.jpg
# 97                                      P91OP4SS16.jpg
# 98                                      P96OP4FA17.jpg
# 100                                     P98OP4FA17.jpg
# 101                                     P99OP4FA17.jpg
# 102                                    P100OP4FA17.jpg
# 103                                    P101GE5IR18.jpg
# 104                                    P102GE5IR18.jpg
# 105                                    P101GE5IR18.jpg
# 107                                    P105GE5WD19.jpg
# 108                                    P106GE5WD19.jpg
# 110                                               None
# 111                                    P109GE5PT20.jpg
# 113                                                .55
#
#                                               LANGUAGE  \
# 10                                                  EN
# 11                                                  EN
# 15                                                  EN
# 16                                                  EN
# 20                                                  EN
# 21                                                  EN
# 23                                                  EN
# 26                                                  EN
# 33                                                  EN
# 34                                      P86OP4IR15.jpg
# 36                                                  EN
# 37                                                  EN
# 38                                                  EN
# 39                                                  EN
# 40                                                  EN
# 41                                                  EN
# 42                                                  EN
# 44                                                  EN
# 48   A perfect tent for biking and hiking trips, co...
# 50                                                  EN
# 55                                                  EN
# 58                                                  EN
# 59                                                  EN
# 62                                                  EN
# 63                                                  EN
# 65                                                  EN
# 69                                                  EN
# 73                                                  EN
# 77                                                  EN
# 90                                                  EN
# 92                                                  EN
# 93   Sun Blocker is waterproof and lasts up to eigh...
# 94                                                  EN
# 95                                                  EN
# 96                                                  EN
# 97                                                  EN
# 98                                                  EN
# 100                                                 EN
# 101                                                 EN
# 102                                                 EN
# 103                                                 EN
# 104                                                 EN
# 105                                                 EN
# 107                                                 EN
# 108                                                 EN
# 110                                                 EN
# 111                                                 EN
# 113                                                 EN
#
#                                           PRODUCT_NAME  \
# 10                                 Mountain Man Analog
# 11   Tough rubber strap, digital face, hardened cry...
# 15                                           Polar Sun
# 16                                           Polar Ice
# 20                                         Single Edge
# 21                                         Double Edge
# 23                                           Bear Edge
# 26                                           Seeker 50
# 33                                   BugShield Natural
# 34                                     BugShield Spray
# 36                                     P114GE5GA21.jpg
# 37                                   Course Pro Gloves
# 38                                 TrailChef Water Bag
# 39                                   TrailChef Canteen
# 40                               TrailChef Kitchen Kit
# 41                                       TrailChef Cup
# 42                                  TrailChef Cook Set
# 44                              TrailChef Single Flame
# 48                                           Star Lite
# 50                                        Star Gazer 2
# 55                                          Hibernator
# 58                                      Hibernator Pad
# 59                                   Hibernator Pillow
# 62                      Canyon Mule Weekender Backpack
# 63                        Canyon Mule Journey Backpack
# 65                                  Canyon Mule Cooler
# 69                                           Firefly 2
# 73                                     EverGlow Single
# 77                                       EverGlow Lamp
# 90                               BugShield Lotion Lite
# 92                                   BugShield Extreme
# 93                                         Sun Blocker
# 94                                   Sun Shelter Stick
# 95                                      Sun Shelter 15
# 96                                      Sun Shelter 30
# 97                                          Sun Shield
# 98                                  Compact Relief Kit
# 100                                    Calamine Relief
# 101                                               None
# 102                                 Insect Bite Relief
# 103                              Hailstorm Steel Irons
# 104                           Hailstorm Titanium Irons
# 105                         Lady Hailstorm Steel Irons
# 107                                               None
# 108                          Hailstorm Steel Woods Set
# 110                     Lady Hailstorm Steel Woods Set
# 111                                  Course Pro Putter
# 113                              Blue Steel Max Putter
#
#                                            DESCRIPTION INTRODUCTION_YEAR
# 10   Padded leather strap, precision Swiss quartz m...              2011
# 11                                Mountain Man Digital              2011
# 15   The Polar Sun sunglasses have 3 mm thick lense...              2011
# 16   Polar Ice sunglasses have polarized lenses to ...              2011
# 20   Single stainless steel blade folding knife. Le...              2011
# 21   Double stainless steel blade folding knife. Le...              2011
# 23   Knife is 33 cm long with a 20 cm blade made of...              2011
# 26   Rubber coated and ergonomically designed. The ...              2011
# 33   Contains no chemicals. Repels mosquitoes, blac...              2011
# 34   Repels black flies, ticks, mosquitoes, chigger...              2011
# 36   High quality golf bag that includes carrying s...              2019
# 37   Durable nylon constructed gloves with stitched...              2019
# 38   Lightweight, collapsible bag to carry liquids ...              2011
# 39   Aluminum canteen. Rugged fleece-lined cover wi...              2011
# 40   Zippered nylon pouch contains cutlery for two,...              2011
# 41             Tin cup. Holds 0.4 liters. Weight: 60 g              2011
# 42   All you will ever need on the trail.  Pot grip...              2011
# 44   A single burner stove with integral tank.  It ...              2011
# 48                                                  EN              2011
# 50   The Star Gazer 2 is the Great Outdoor's most v...              2011
# 55                                                None              2011
# 58   Warms up quickly for snow camping comfort. The...              2011
# 59   Camp pillow is filled with soft, luxurious fib...              2011
# 62   A weekend getaway requires this pack.  It feat...              2011
# 63   Set of three packs: handlebar pack, front pack...              2011
# 65   A durable plastic cooler with hinged top, perf...              2011
# 69                                               16.67              2011
# 73   Light output approximates a 100 W bulb. Single...              2011
# 77   Perfect for in your tent, this lamp comes with...              2011
# 90   Repels black flies, ticks, mosquitoes, chigger...              2011
# 92   Highest amount of the active ingredient, 38%, ...              2011
# 93                                                  EN              2011
# 94   Easy to apply to your nose, lips, ears and oth...              2011
# 95           SPF 15 protects against all harmful rays.              2011
# 96   SPF 30 provides maximum protection and is long...              2011
# 97   PABA free sunscreen, SPF 30, poison oak and iv...              2011
# 98   A personal first aid kit is recommended for ev...              2011
# 100  Use the Calamine Relief for allergic skin reac...              2011
# 101  Perfect for minor burns and sunburn, the aloe ...              2011
# 102  The Insect Bite Relief helps the itching and s...              2011
# 103  Iron is 17-4 stainless steel.  Shafts are grap...              2019
# 104  Made entirely of pure titanium. The ultimate i...              2019
# 105  Iron is 17-4 stainless steel.  Shafts are grap...              2019
# 107  Crafted of 6-4 titanium which is 40% lighter a...              2019
# 108  These steel woods are manufactured to exact to...              2019
# 110  These steel woods are manufactured to exact to...              2019
# 111  High quality putter is cast  from a soft yello...              2019
# 113  Putter head is composed from a single piece of...              2019

# %% [markdown]
# Hmm... nogal onoverzichtelijk he. Gelukkig kunnen we, net als in SQL, groeperen op introductiejaar en producttypecode, om vervolgens met count() het aantal rijen te tellen. 'PRODUCT_NUMBER' kan misschien verwarrend zijn, je moet namelijk jammer genoeg per se een kolom uitkiezen waarvan de rijen geteld worden. Om deze verwarring weg te nemen wijzigen we maar snel deze kolomnaam naar 'Aantal producten'.

# %%
grouped_subset_introduction_year_2011_2019 = subset_introduction_year_2011_2019.groupby(['INTRODUCTION_YEAR', 'PRODUCT_TYPE_CODE'])['PRODUCT_NUMBER'].count().reset_index()
grouped_subset_introduction_year_2011_2019 = grouped_subset_introduction_year_2011_2019.rename(columns = {'PRODUCT_NUMBER' : 'Aantal producten'})
grouped_subset_introduction_year_2011_2019.sort_values(['INTRODUCTION_YEAR', 'Aantal producten'], ascending = [True, False])
# Out:
#    INTRODUCTION_YEAR PRODUCT_TYPE_CODE  Aantal producten
# 0               2011                 1                 6
# 6               2011                16                 5
# 5               2011                15                 4
# 7               2011                17                 4
# 3               2011                12                 3
# 9               2011                 3                 3
# 11              2011                 5                 3
# 1               2011                10                 2
# 8               2011                 2                 2
# 10              2011                 4                 2
# 2               2011                11                 1
# 4               2011                13                 1
# 13              2019                19                 3
# 12              2019                18                 2
# 14              2019                20                 2
# 15              2019                21                 1

# %% [markdown]
# We zien dat in jaartal 2011 producttypecode 1 het vaakst voorkomt, in jaartal 2019 is dat producttypecode 19. Hiermee kunnen we de lege waarden vullen.

# %%
product.loc[(product['INTRODUCTION_YEAR'] == '2011'), 'PRODUCT_TYPE_CODE'] = product.loc[(product['INTRODUCTION_YEAR'] == '2011'), 'PRODUCT_TYPE_CODE'].fillna(1)
product.loc[(product['INTRODUCTION_YEAR'] == '2019'), 'PRODUCT_TYPE_CODE'] = product.loc[(product['INTRODUCTION_YEAR'] == '2019'), 'PRODUCT_TYPE_CODE'].fillna(19)
product['PRODUCT_TYPE_CODE'].isna().sum()
# Out:
# 0

# %% [markdown]
# Wederom willen we een gedeelte van het originele dataframe ('product') overschrijven (linkerkant '='). Het aantal lege waarden in PRODUCT_TYPE zou nu 0 moeten zijn en dat klopt! Yay for us :-D
