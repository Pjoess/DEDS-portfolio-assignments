# %%
import pandas as pd
import pyodbc

# %%
sales_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/Tim/Desktop/GO-databases DEDS-week 4 & 5/go_sales.accdb;')
staff_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/Tim/Desktop/GO-databases DEDS-week 4 & 5/go_staff.accdb;')
crm_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/Tim/Desktop/GO-databases DEDS-week 4 & 5/go_crm.accdb;')

# %%
product = pd.read_sql("SELECT * FROM product", sales_conn)
product
# Out:
# C:\Users\Tim\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     PRODUCT_NUMBER  INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST  \
# 0               53          10-1-2021                 8           28.55
# 1               54          10-1-2021                 8           35.33
# 2               55               None                 8               4
# 3               56          10-1-2021                 8               9
# 4               57          10-1-2021                 9              40
# ..             ...                ...               ...             ...
# 110            108         27-12-2019                19          472.22
# 111            109         10-12-2019                20              35
# 112            110  Blue Steel Putter                20              60
# 113            111         15-12-2019                20            81.8
# 114            112          10-1-2020                21               6
#
#               MARGIN    PRODUCT_IMAGE LANGUAGE  \
# 0                .28    P53ME2CA8.jpg       EN
# 1                .33    P54ME2CA8.jpg     None
# 2                 .5    P55ME2CA8.jpg       EN
# 3                 .5    P56ME2CA8.jpg     None
# 4                 .5    P57ME2TL9.jpg       EN
# ..               ...              ...      ...
# 110              .43             None       EN
# 111              .43  P109GE5PT20.jpg       EN
# 112               .5  P110GE5PT20.jpg       EN
# 113  P111GE5PT20.jpg              .55       EN
# 114              .33             None       EN
#
#                        PRODUCT_NAME  \
# 0             Firefly Climbing Lamp
# 1                   Firefly Charger
# 2      Firefly Rechargeable Battery
# 3                 Granite Chalk Bag
# 4                       Granite Ice
# ..                              ...
# 110  Lady Hailstorm Steel Woods Set
# 111               Course Pro Putter
# 112                      10-12-2019
# 113           Blue Steel Max Putter
# 114     Course Pro Golf and Tee Set
#
#                                            DESCRIPTION
# 0    This climbing lamp is water-resistant. It come...
# 1    Power charger for the Firefly Climbing Lamp. T...
# 2    Rechargeable battery pack for the Firefly Clim...
# 3    Nylon web bag perfect for holding several stic...
# 4    A general purpose mountaineering axe for snow ...
# ..                                                 ...
# 110  These steel woods are manufactured to exact to...
# 111  High quality putter is cast  from a soft yello...
# 112  This premium putter has copper mixed with ligh...
# 113  Putter head is composed from a single piece of...
# 114  Set includes two premium golf ball and an asso...
#
# [115 rows x 9 columns]

# %%
types = pd.read_sql("SELECT * FROM product_type", sales_conn)
types
# Out:
# C:\Users\Tim\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    PRODUCT_TYPE_CODE PRODUCT_LINE_CODE       PRODUCT_TYPE_EN
# 0                  1                 1          Cooking Gear
# 1                  2              None                 Tents
# 2                  3                 1         Sleeping Bags
# 3                  4                 1                 Packs
# 4                  5                 1              Lanterns
# 5                  6                 2                  None
# 6                  7                 2                  None
# 7                  8                 2  Climbing Accessories
# 8                  9              None                 Tools
# 9                 10                 3               Watches
# 10                11              None               Eyewear
# 11                12                 3                Knives
# 12                13                 3            Binoculars
# 13                14                 3            Navigation
# 14                15                 4     Insect Repellents
# 15                16                 4             Sunscreen
# 16                17                 4             First Aid
# 17                18                 5                 Irons
# 18                19              None                 Woods
# 19                20                 5               Putters
# 20                21                 5      Golf Accessories

# %%
joined = pd.merge(product, types, on = 'PRODUCT_TYPE_CODE', how = 'inner')
joined
# Out:
#     PRODUCT_NUMBER  INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST  \
# 0               53          10-1-2021                 8           28.55
# 1               54          10-1-2021                 8           35.33
# 2               55               None                 8               4
# 3               56          10-1-2021                 8               9
# 4               50          10-1-2021                 8               2
# ..             ...                ...               ...             ...
# 104            107          13-1-2020                19          509.07
# 105            108         27-12-2019                19          472.22
# 106            109         10-12-2019                20              35
# 107            110  Blue Steel Putter                20              60
# 108            111         15-12-2019                20            81.8
#
#               MARGIN    PRODUCT_IMAGE LANGUAGE  \
# 0                .28    P53ME2CA8.jpg       EN
# 1                .33    P54ME2CA8.jpg     None
# 2                 .5    P55ME2CA8.jpg       EN
# 3                 .5    P56ME2CA8.jpg     None
# 4                 .5    P50ME2CA8.jpg       EN
# ..               ...              ...      ...
# 104              .55  P105GE5WD19.jpg       EN
# 105              .43             None       EN
# 106              .43  P109GE5PT20.jpg       EN
# 107               .5  P110GE5PT20.jpg       EN
# 108  P111GE5PT20.jpg              .55       EN
#
#                           PRODUCT_NAME  \
# 0                Firefly Climbing Lamp
# 1                      Firefly Charger
# 2         Firefly Rechargeable Battery
# 3                    Granite Chalk Bag
# 4                    Granite Carabiner
# ..                                 ...
# 104  Lady Hailstorm Titanium Woods Set
# 105     Lady Hailstorm Steel Woods Set
# 106                  Course Pro Putter
# 107                         10-12-2019
# 108              Blue Steel Max Putter
#
#                                            DESCRIPTION PRODUCT_LINE_CODE  \
# 0    This climbing lamp is water-resistant. It come...                 2
# 1    Power charger for the Firefly Climbing Lamp. T...                 2
# 2    Rechargeable battery pack for the Firefly Clim...                 2
# 3    Nylon web bag perfect for holding several stic...                 2
# 4    Made from 12 mm rod stock aluminum and a radiu...                 2
# ..                                                 ...               ...
# 104  Crafted of 6-4 titanium which is 40% lighter a...              None
# 105  These steel woods are manufactured to exact to...              None
# 106  High quality putter is cast  from a soft yello...                 5
# 107  This premium putter has copper mixed with ligh...                 5
# 108  Putter head is composed from a single piece of...                 5
#
#           PRODUCT_TYPE_EN
# 0    Climbing Accessories
# 1    Climbing Accessories
# 2    Climbing Accessories
# 3    Climbing Accessories
# 4    Climbing Accessories
# ..                    ...
# 104                 Woods
# 105                 Woods
# 106               Putters
# 107               Putters
# 108               Putters
#
# [109 rows x 11 columns]

# %%
product_ster = joined.drop(['LANGUAGE','PRODUCT_IMAGE','INTRODUCTION_DATE','PRODUCTION_COST','MARGIN','DESCRIPTION','PRODUCT_LINE_CODE'], axis = 1)
product_ster
# Out:
#     PRODUCT_NUMBER PRODUCT_TYPE_CODE                       PRODUCT_NAME  \
# 0               53                 8              Firefly Climbing Lamp
# 1               54                 8                    Firefly Charger
# 2               55                 8       Firefly Rechargeable Battery
# 3               56                 8                  Granite Chalk Bag
# 4               50                 8                  Granite Carabiner
# ..             ...               ...                                ...
# 104            107                19  Lady Hailstorm Titanium Woods Set
# 105            108                19     Lady Hailstorm Steel Woods Set
# 106            109                20                  Course Pro Putter
# 107            110                20                         10-12-2019
# 108            111                20              Blue Steel Max Putter
#
#           PRODUCT_TYPE_EN
# 0    Climbing Accessories
# 1    Climbing Accessories
# 2    Climbing Accessories
# 3    Climbing Accessories
# 4    Climbing Accessories
# ..                    ...
# 104                 Woods
# 105                 Woods
# 106               Putters
# 107               Putters
# 108               Putters
#
# [109 rows x 4 columns]
